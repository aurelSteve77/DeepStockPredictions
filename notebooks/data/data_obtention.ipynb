# %%
import pandas as pd
import json
import numpy as np

# %%
liste = []
with open('../../data/raw/investment_tweets2.json', encoding='utf16') as f:
    for line in f:
        liste.append(json.loads(line))

# %%
df = pd.DataFrame(liste)

# %%
df.to_csv('../../data/raw/investments_news_tweet.csv')

# %%
df.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/InvestirFr/status/14490615...
# 1  https://twitter.com/InvestirFr/status/14490499...
# 2  https://twitter.com/InvestirFr/status/14490451...
# 3  https://twitter.com/InvestirFr/status/14490197...
# 4  https://twitter.com/InvestirFr/status/14490184...
#
#                         date  \
# 0  2021-10-15T17:16:09+00:00
# 1  2021-10-15T16:30:06+00:00
# 2  2021-10-15T16:10:49+00:00
# 3  2021-10-15T14:30:15+00:00
# 4  2021-10-15T14:25:00+00:00
#
#                                              content  \
# 0  40.000 nouveaux actionnaires individuels https...
# 1  [Agenda] Retrouvez les grands rendez-vous de l...
# 2  Clôture : encourageant, le début de la saison ...
# ...
